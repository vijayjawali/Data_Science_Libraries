# %% [markdown]
# ### PLOTLY DASH

# %% [markdown]
# <img src="plotly_dash_image.jpeg">

# %% [markdown]
# https://dash.plotly.com/

# %%
! pip install dash
! pip install dash-core-components
! pip install dash-html-components
! pip install dash-renderer
# Out:
# ...
#   Using cached dash_table-5.0.0.tar.gz (3.4 kB)
# ...
#   Using cached Flask_Compress-1.10.1-py3-none-any.whl (7.9 kB)
# ...
#   Using cached dash_core_components-2.0.0.tar.gz (3.4 kB)
# ...
#   Using cached dash_html_components-2.0.0.tar.gz (3.8 kB)
# ...
#   Using cached itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# ...
#   Created wheel for dash-core-components: filename=dash_core_components-2.0.0-py3-none-any.whl size=3803 sha256=dda7f937bb87882b58d262cdf43e6ae8b2b80bb4fba80765569aee65efc481a6
#   Stored in directory: c:\users\vijay\appdata\local\pip\cache\wheels\33\9a\90\712df38094bc4a9193bc098f5be9c83e453e2947ec11669f13
# ...
#   Created wheel for dash-html-components: filename=dash_html_components-2.0.0-py3-none-any.whl size=4071 sha256=caf609c8d42c019b63e11a5f26534a07e74ff450f5d9162a1ff6eac2f440ab1a
#   Stored in directory: c:\users\vijay\appdata\local\pip\cache\wheels\78\dc\78\25653638f8071b4c41736c69c1da793e8dfad383364bcb246d
# ...

# %%
import dash
from dash import dcc as dcc
from dash import html as html

# %%
app = dash.Dash()

# %%
app.layout = html.Div([
    html.H1('Hello Dash'),
    html.Div('Dash: A web application framework for Python.')
])

# %%
if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
help(html.Div)
# Out:
# Help on class Div in module dash.html.Div:
#
# class Div(dash.development.base_component.Component)
#  |  A Div component.
#  |  Div is a wrapper for the <div> HTML5 element.
#  |  For detailed attribute info see:
#  |  https://developer.mozilla.org/en-US/docs/Web/HTML/Element/div
#  |
#  |  Keyword arguments:
#  |
#  |  - children (a list of or a singular dash component, string or number; optional):
#  |      The children of this component.
#  |
#  |  - id (string; optional):
#  |      The ID of this component, used to identify dash components in
#  |      callbacks. The ID needs to be unique across all of the components
#  |      in an app.
#  |
#  |  - accessKey (string; optional):
#  |      Keyboard shortcut to activate or add focus to the element.
#  |
#  |  - aria-* (string; optional):
#  |      A wildcard aria attribute.
#  |
#  |  - className (string; optional):
#  |      Often used with CSS to style elements with common properties.
#  |
# ...

# %%
help(dcc.Dropdown)
# Out:
# Help on class Dropdown in module dash.dcc.Dropdown:
#
# class Dropdown(dash.development.base_component.Component)
#  |  A Dropdown component.
#  |  Dropdown is an interactive dropdown element for selecting one or more
#  |  items.
#  |  The values and labels of the dropdown items are specified in the `options`
#  |  property and the selected item(s) are specified with the `value` property.
#  |
#  |  Use a dropdown when you have many options (more than 5) or when you are
#  |  constrained for space. Otherwise, you can use RadioItems or a Checklist,
#  |  which have the benefit of showing the users all of the items at once.
#  |
#  |  Keyword arguments:
#  |
#  |  - options (list of dicts; optional):
#  |      An array of options {label: [string|number], value:
#  |      [string|number]}, an optional disabled field can be used for each
#  |      option.
#  |
#  |      `options` is a list of string | number | booleans | dict | list of
#  |      dicts with keys:
#  |
# ...

# %% [markdown]
# ### Getting Startred with Dash

# %%
app.layout = html.Div([
    html.H1('Hello Dash !!!'),
    html.Div('Dash: A web application framework for Python.'),

    dcc.Graph(
        id='Sample Graph',
        figure={
            'data': [
                {'x': [5, 6, 7, 8],
                 'y': [12, 15, 18, 19],
                 'type': 'bar',
                 'name':'Bar Graph'},
                {'x': [5, 6, 7, 8],
                 'y': [18, 25, 38, 49],
                 'type': 'bar',
                 'name':'Bar Graph'}
            ],
            'layout': {
                'title': 'Simple bar Graph'
            }
        }
    )
])

# %%
if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Bar Charts

# %%
app.layout = html.Div([
    html.H1(children='Hello Dash !!!',
            style={'textAlign': 'center',
                   'color': '#7FDBFF'}
            ),
    html.Div(children='Dash: A web application framework for Python.',
            style={'textAlign': 'center',
                   'color': '#7FDBFF'}
            ),

    dcc.Graph(
        id='Sample Graph',
        figure={
            'data': [
                {'x': [5, 6, 7, 8],
                 'y': [12, 15, 18, 19],
                 'type': 'bar',
                 'name':'Bar Graph'},
                {'x': [5, 6, 7, 8],
                 'y': [18, 25, 38, 49],
                 'type': 'bar',
                 'name':'Bar Graph'}
            ],
            'layout': {
                'title': 'Simple bar Graph'
            }
        }
    )
])

if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
app.layout = html.Div([
    html.H1(children='Hello Dash !!!',
            style={'textAlign': 'center',
                   'color': '#7FDBFF'}
            ),
    html.Div(children='Dash: A web application framework for Python.',
            style={'textAlign': 'center',
                   'color': '#7FDBFF'}
            ),

    dcc.Graph(
        id='Sample Graph',
        figure={
            'data': [
                {'x': [5, 6, 7, 8],
                 'y': [12, 15, 18, 19],
                 'type': 'bar',
                 'name':'Bar Graph'},
                {'x': [5, 6, 7, 8],
                 'y': [18, 25, 38, 49],
                 'type': 'bar',
                 'name':'Bar Graph'}
            ],
            'layout': {
                'plot_bgcolor' : '#D3D3D3',
                'paper_bgcolor' : '#00FFFF',
                'font' : {
                    'color' : '#FF0000'
                },
                'title': 'Simple bar Graph'
            }
        }
    )
])

if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
colors = {
    'text': '#7FDBFF',
    'plot_color' : '#D3D3D3',
    'paper_color' : '#00FFFF',
    'layout_text' : '#FF0000'
}

# %%
app.layout = html.Div([
    html.H1(children='Hello Dash !!!',
            style={'textAlign': 'center',
                   'color': colors['text']}
            ),
    html.Div(children='Dash: A web application framework for Python.',
            style={'textAlign': 'center',
                   'color': colors['text']}
            ),

    dcc.Graph(
        id='Sample Graph',
        figure={
            'data': [
                {'x': [5, 6, 7, 8],
                 'y': [12, 15, 18, 19],
                 'type': 'bar',
                 'name':'Bar Graph'},
                {'x': [5, 6, 7, 8],
                 'y': [18, 25, 38, 49],
                 'type': 'bar',
                 'name':'Bar Graph'}
            ],
            'layout': {
                'plot_bgcolor' : colors['plot_color'],
                'paper_bgcolor' : colors['paper_color'],
                'font' : {
                    'color' : colors['layout_text']
                },
                'title': 'Simple bar Graph'
            }
        }
    )
])

if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Scatter Charts

# %%
import numpy as np
import plotly.graph_objs as go

# %%
np.random.seed(50)
x_rand = np.random.randint(1, 61, 60)
y_rand = np.random.randint(1, 61, 60)

# %%
app.layout = html.Div([
    dcc.Graph(
        id='Scatter Plot',
        figure={
            'data': [
                go.Scatter(x=x_rand,
                           y=y_rand,
                           mode='markers')
            ],
            'layout': go.Layout(
                title='Scatter Plot of Random 60 points',
                xaxis={'title': 'Random X values'},
                yaxis={'title': 'Random Y values'} 
            )
        }      
    )
])

if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
import pandas as pd
app = dash.Dash()

# %%
orders = pd.read_excel(r'sales.xlsx', sheet_name="Orders", engine='openpyxl')

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
app.layout = html.Div([
    dcc.Graph(
        id='Scatter Plot',
        figure={
            'data': [
                go.Scatter(x=orders.Sales,
                           y=orders.Profit,
                           mode='markers')
            ],
            'layout': go.Layout(
                title='Scatter Plot of Random 60 points',
                xaxis={'title': 'Sales'},
                yaxis={'title': 'Profit'} 
            )
        }      
    )
])

if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
# Dash is running on http://127.0.0.1:4050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Dropdown Selector

# %%
app = dash.Dash()

# %%
app.layout = html.Div([
    html.Label('Choose a city'),
    html.Br(),
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [{'label': 'San Francisco', 'value': 'SF'},
                   {'label': 'Montreal', 'value': 'MTL'},
                   {'label': 'Vancouver', 'value': 'VAN'}
        ],
        value = 'SF',
        multi = True
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [{'label': 'San Francisco', 'value': 'SF'},
                   {'label': 'Montreal', 'value': 'MTL'},
                   {'label': 'Vancouver', 'value': 'VAN'}
        ],
        placeholder = 'Select a city'
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [{'label': 'San Francisco', 'value': 'SF'},
                   {'label': 'Montreal', 'value': 'MTL'},
                   {'label': 'Vancouver', 'value': 'VAN'}
        ],
        disabled = True
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [{'label': 'San Francisco', 'value': 'SF'},
                   {'label': 'Montreal', 'value': 'MTL'},
                   {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
        ],
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Slider

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [{'label': 'San Francisco', 'value': 'SF'},
                   {'label': 'Montreal', 'value': 'MTL'},
                   {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
        ],
    ),
    html.Label("This is a Slider"),
    dcc.Slider(min = 0, 
               max = 10, 
               step = 0.5, 
               value = 50, 
               id = 'first-slider')
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Range Slider

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3,7],
                    id='first-slider')
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Text Input Box

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...')
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Text Area

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Textarea(id='first-textarea',
                 placeholder='Enter a value...',
                 value='Enter a value...',
                 style={'width': '100%', 'height': '100px'})

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Checkbox

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Textarea(id='first-textarea',
                 placeholder='Enter a value...',
                 value='Enter a value...',
                 style={'width': '100%', 'height': '100px'}),
    
    html.Br(),
    html.Br(),
    dcc.Checklist(
         options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
         value = ['MTL', 'SF'],
    )

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Radio Button

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Textarea(id='first-textarea',
                 placeholder='Enter a value...',
                 value='Enter a value...',
                 style={'width': '100%', 'height': '100px'}),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Checklist(
         options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
         value = ['MTL', 'SF']
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.RadioItems(
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
        value = 'MTL'
    )

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Buttons

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Textarea(id='first-textarea',
                 placeholder='Enter a value...',
                 value='Enter a value...',
                 style={'width': '100%', 'height': '100px'}),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Checklist(
         options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
         value = ['MTL', 'SF']
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.RadioItems(
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
        value = 'MTL'
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    
    html.Button('Submit', id='button')
    

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Date Picker

# %%
from datetime import datetime as dt

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Textarea(id='first-textarea',
                 placeholder='Enter a value...',
                 value='Enter a value...',
                 style={'width': '100%', 'height': '100px'}),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Checklist(
         options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
         value = ['MTL', 'SF']
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.RadioItems(
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
        value = 'MTL'
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    html.Button('Submit', id='button'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.DatePickerSingle(
        id = 'first-date-picker',
        date = dt(2020, 1, 1)
    )

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
app.layout = html.Div([
    html.Br(),
    dcc.Dropdown(
        id='first-dropdown',
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True}
                 ],
    ),
    html.Label("This is a Range Slider"),
    dcc.RangeSlider(min=0,
                    max=10,
                    step=0.5,
                    value=[3, 7],
                    id='first-slider'),
    html.Br(),
    html.Br(),
    html.Br(),
    html.Label("This is Input"),
    html.Br(),
    dcc.Input(id='first-input',
              type='text',
              value='Enter a value',
              placeholder='Enter a value...'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Textarea(id='first-textarea',
                 placeholder='Enter a value...',
                 value='Enter a value...',
                 style={'width': '100%', 'height': '100px'}),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.Checklist(
         options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
         value = ['MTL', 'SF']
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.RadioItems(
        options=[{'label': 'San Francisco', 'value': 'SF'},
                 {'label': 'Montreal', 'value': 'MTL'},
                 {'label': 'Vancouver', 'value': 'VAN', 'disabled': True},
                 {'label': 'New York', 'value': 'NYC'}
                 ],
        value = 'MTL'
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    html.Button('Submit', id='button'),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.DatePickerSingle(
        id = 'first-date-picker',
        date = dt(2020, 1, 1)
    ),
    
    html.Br(),
    html.Br(),
    html.Br(),
    dcc.DatePickerRange(
        id='first-date-picker-range',
        start_date = dt(2012, 1, 1),
        end_date_placeholder_text = 'Select end date!',
    )

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ### Markdown

# %%
app.layout = html.Div([
    dcc.Markdown('''
    ### Dash and Markdown
    
    Dash supports [Markdown](http://commonmark.org/help).
    
    Markdown is a simple way to write and format text.
    It includes a syntax for things like **bold text** and *italics*,
    [links](http://commonmark.org/help), inline `code` snippets, lists,
    quotes, and more.
    '''
    )

])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
